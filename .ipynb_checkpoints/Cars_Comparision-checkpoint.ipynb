# %%
import numpy as np
import pandas as pd

cars_pl = pd.read_csv("CARS_PL.csv", sep=";")
cars_nl = pd.read_csv("CARS_NL.csv", sep=";")
cars_uk = pd.read_csv("CARS_UK.csv",sep=";")
cars_de = pd.read_csv("CARS_DE.csv", sep=";")
cars_us = pd.read_csv("CARS_US.csv", sep=";")

# %%
columns = ['country', 'model', 'year', 'mileage', 'price']

cars_pl.head()
# Out:
#   country model             name  year   mileage     fuel   price
# 0      PL  ford        Ford Kuga  2018  172 890    Diesel  67 800
# 1      PL  ford        Ford Kuga  2010  101 000    Diesel  34 900
# 2      PL  ford  Ford Fiesta Mk7  2010  124 590   Benzyna  16 900
# 3      PL  ford  Ford Galaxy 2.0  2010  257 000    Diesel  31 500
# 4      PL  ford    Ford Kuga 2.0  2009  218 000    Diesel  36 600

# %%
from currency_converter import CurrencyConverter

curr = CurrencyConverter()

# %%
for col_id, row in cars_pl.iterrows():
    pr = row['price'].replace(" ", "")
    euro = curr.convert(int(pr), 'PLN', "EUR")
    cars_pl.at[col_id, 'euros'] = round(euro, 2)
    
cars_pl.head(5)
# Out:
#   country model             name  year   mileage     fuel   price     euros
# 0      PL  ford        Ford Kuga  2018  172 890    Diesel  67 800  15828.18
# 1      PL  ford        Ford Kuga  2010  101 000    Diesel  34 900   8147.54
# 2      PL  ford  Ford Fiesta Mk7  2010  124 590   Benzyna  16 900   3945.37
# 3      PL  ford  Ford Galaxy 2.0  2010  257 000    Diesel  31 500   7353.80
# 4      PL  ford    Ford Kuga 2.0  2009  218 000    Diesel  36 600   8544.41

# %%
for col_id, row in cars_uk.iterrows():
    pr = row['price']
    euro = curr.convert(int(pr), 'GBP', "EUR")
    cars_uk.at[col_id, 'euros'] = round(euro, 2)
    
cars_uk.head(5)
# Out:
#   country model                                   name  year  mileage    fuel  \
# 0      UK  ford  Ford Mondeo 2.0 TDCi 140 Zetec 5 door  2013   83 329  Diesel
# 1      UK  ford             Ford Fiesta 1.25 Zetec 3dr  2005   75 000  Petrol
# 2      UK  ford          Ford Focus 1.6 i 16v Ghia 5dr  2002  159 000  Petrol
# 3      UK  ford   Ford Focus 1.6 TDCi ECOnetic DPF 5dr  2010  129 300  Diesel
# 4      UK  ford           Ford C-Max 1.6 16v Style 5dr  2008   82 000  Petrol
#
#    price    euros
# 0   4989  5974.13
# 1    850  1017.84
# 2    200   239.49
# 3   1495  1790.20
# 4   1490  1784.22

# %%
for col_id, row in cars_us.iterrows():
    pr = row['price']
    euro = curr.convert(int(pr), 'USD', "EUR")
    cars_us.at[col_id, 'euros'] = round(euro, 2)
    
cars_us.head(5)
# Out:
#   country model                    name  year  mileage    price     euros
# 0      US  ford       Ford Explorer XLT  2017    34863  25089.0  23228.40
# 1      US  ford  Ford Explorer Platinum  2016    39710  29386.0  27206.74
# 2      US  ford     Ford Taurus Limited  2019    46484  19963.0  18482.55
# 3      US  ford       Ford Explorer XLT  2014   139341  12990.0  12026.66
# 4      US  ford     Ford Taurus Limited  2016    53555  17995.0  16660.49

# %%
import scipy.stats as norm
import seaborn

seaborn.set()

CARS = [
    "ford",
    "bmw",
    "fiat",
    "toyota",
    "peugeot",
    "audi",
    "mercedes",
    "volvo",
    "nissan",
    "suzuki",
    "volkswagen",
    "renault",
    "skoda",
    "opel"
]

# %%
cars_model_mean_pl = (cars_pl.query("model in @CARS")
                .groupby('model', sort=False)['euros']
                .agg(['size', 'mean'])
                .round({'mean':2})
)

cars_model_mean_pl
# Out:
#             size      mean
# model
# ford          32   8103.73
# bmw           32  16407.83
# fiat          32   7639.96
# toyota        32   8702.68
# peugeot       32   6411.27
# audi          35  19329.83
# volkswagen    36  16651.10
# volvo         32  17377.70
# nissan        32  16714.84
# suzuki        32   9501.74
# renault       32   6446.58
# skoda         32  15118.67
# opel          32   7986.30

# %%
cars_year_mean_pl = (cars_pl.query("model in @CARS")
                .groupby('model', sort=False)['year']
                .agg(['mean'])
                .round({'mean':0})
)

cars_year_mean_pl
# Out:
#               mean
# model
# ford        2011.0
# bmw         2012.0
# fiat        2013.0
# toyota      2011.0
# peugeot     2011.0
# audi        2011.0
# volkswagen  2015.0
# volvo       2013.0
# nissan      2016.0
# suzuki      2012.0
# renault     2011.0
# skoda       2016.0
# opel        2012.0

# %%
PL_DATA = pd.DataFrame({'Model':cars_model_mean_pl.index, 'Price (€)':cars_model_mean_pl['mean']})
ax = PL_DATA.plot(kind="bar", x='Model', y='Price (€)', rot=0, figsize=(12, 5)).margins(10, None)

# %%
PL_DATA = pd.DataFrame({'Year':cars_year_mean_pl['mean'],
                        'Price (€)':cars_model_mean_pl['mean']},
                       index=(cars_model_mean_pl.index))
ax = PL_DATA.plot(kind="bar", rot=0, figsize=(12, 5)).margins(10, None)
